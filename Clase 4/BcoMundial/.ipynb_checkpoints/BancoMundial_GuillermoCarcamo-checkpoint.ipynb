# %% [markdown]
# # 1. Importar librerías y cargar datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Cargar dataset
pib = pd.read_csv("pib_banco_mundial_50.csv", sep=";").rename(columns={
    "Country Name": "Pais",
    "Country Code": "Codigo",
    "2019": "PIB_2019",
    "2020": "PIB_2020",
    "2021": "PIB_2021",
    "2022": "PIB_2022",
    "2023": "PIB_2023"
})

anios = ["PIB_2019","PIB_2020","PIB_2021","PIB_2022","PIB_2023"]

# y = PIB mundial (fila World)
y = pib[pib["Pais"].str.lower()=="world"][anios].values.reshape(-1,1)

# Utilizo Tail ya que solo quiero ver la parte final del df, y ver la ultima fila World
pib.tail()
# Out:
#            Pais Codigo      PIB_2019      PIB_2020      PIB_2021  \
# 46      Hungary    HUN  2.118500e+12  1.562700e+12  2.447900e+12
# 47       Greece    GRC  7.337000e+11  3.544000e+11  5.649000e+11
# 48     Portugal    PRT  1.138000e+11  1.863200e+12  1.225700e+12
# 49  Netherlands    NLD  9.981000e+11  2.374600e+12  2.095300e+12
# 50        World    WLD  5.857570e+13  6.451670e+13  6.172130e+13
#
#         PIB_2022      PIB_2023
# 46  2.110900e+12  1.707900e+12
# 47  3.052000e+11  1.391700e+12
# 48  4.290000e+10  2.257800e+12
# 49  1.860600e+12  1.628000e+12
# 50  6.391170e+13  6.948090e+13

# %% [markdown]
# # Variable dependiente

# %%
y = pib[pib["Pais"].str.lower()=="world"][anios].values.reshape(-1,1)

# %% [markdown]
# # Función para modelos

# %%
def r2_combo(paises):
    X = pib.set_index("Pais").loc[paises, anios].T.values #Variable independiente
    modelo = LinearRegression().fit(X, y)
    return modelo.score(X, y)

# %% [markdown]
# # 4) Ejemplos de combinaciones

# %%
print("Argentina:", r2_combo(["Argentina"]))
print("Argentina + Brasil:", r2_combo(["Argentina","Brazil"]))
print("EEUU + China + India:", r2_combo(["United States","China","India"]))
# Out:
# Argentina: 0.0034724099935826702
# Argentina + Brasil: 0.14242297379497848
# EEUU + China + India: 0.7620320195804535

# %% [markdown]
# # Visualización

# %%
def visualizar_combo(paises):
    # Definir X (PIB de los países) e y (PIB mundial)
    X = pib.set_index("Pais").loc[paises, anios].T.values
    y = pib[pib["Pais"].str.lower()=="world"][anios].values.reshape(-1,1)

    # Ajustar modelo
    modelo = LinearRegression().fit(X, y)
    y_pred = modelo.predict(X)
    r2 = modelo.score(X, y)

    # ---- 1. Serie temporal ----
    plt.figure(figsize=(10,4))
    plt.plot(anios, y, marker="o", label="PIB Mundial real")
    plt.plot(anios, y_pred, marker="s", label=f"Modelo {paises}")
    plt.title(f"Serie temporal: {paises} vs PIB Mundial (R²={r2:.3f})")
    plt.ylabel("PIB (USD)")
    plt.xlabel("Años")
    plt.legend()
    plt.grid(True)
    plt.show()

    # ---- 2. Dispersión real vs predicho ----
    plt.figure(figsize=(5,5))
    plt.scatter(y, y_pred, color="blue")
    plt.plot([y.min(), y.max()], [y.min(), y.max()], color="red", linestyle="--", label="Línea ideal")
    plt.title(f"Real vs Predicho ({paises})")
    plt.xlabel("PIB Mundial real")
    plt.ylabel("PIB Mundial predicho")
    plt.legend()
    plt.show()

# %%
# Un país
visualizar_combo(["Argentina"])

# Dos países
visualizar_combo(["Argentina","Brazil"])

# Tres países
visualizar_combo(["United States","China","India"])

# Cuatro países
visualizar_combo(["United States","China","India","Japan"])
